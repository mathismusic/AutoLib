# %%
from dfa import dfa
from nfa import nfa

# %%
Q = ['q0', 'q1', 'q2']
A = ['0', '1']
Q_0 = {'q0'}
F = ['q2']
M = nfa(Q, A, Q_0, F, name='M')
M.add_edge('q0', 'q1', '0')
M.add_edge('q0', 'q2', '0')
M.draw()

# %%
d = M.to_dfa()
d.Q_0
# Out:
# yee 1
# []
# yee 0
# []
# yee 1
# []
# yee 0
# []
# yee 1
# []
# yee 0
# [{'q2', 'q1'}]
# yee 1
# []
# yee 0
# [{'q2', 'q1'}]
# yee 1
# []
# yee 0
# [{'q2', 'q1'}]
# yee 1
# []
# yee 0
# []
# yee 1
# []
# yee 0
# [{'q2', 'q1'}]
# frozenset({'q0'})

# %%
d.draw()

# %%
# test minimization
d.remove_unreachable_states().draw()
